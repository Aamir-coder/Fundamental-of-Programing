# %%
x=45
y=67
print(x+y)
# Out:
# 112

# %%
x=100
y=35
print(x-y)
# Out:
# 65

# %%
x=23
y=12
print(x*y)
# Out:
# 276

# %%
x=144
y=12
print(x/y)
# Out:
# 12.0

# %%
x=29
y=5
print(x//y)
# Out:
# 5

# %%
x=75
y=8
print(x%y)
# Out:
# 3

# %%
x=5
y=4
print(x**y)
# Out:
# 625

# %%
x=25
y=7
print(x+y,x-y,x*y,x/y,x//y,x%y,x**y)
# Out:
# 32 18 175 3.5714285714285716 3 4 6103515625

# %%
x=10
y=5
print(x+y,x-y,x*y,x/y)
# Out:
# 15 5 50 2.0

# %%
x=[12,4,5,7,8]
mean=sum(x)/len(x)
print(mean)
# Out:
# 7.2
